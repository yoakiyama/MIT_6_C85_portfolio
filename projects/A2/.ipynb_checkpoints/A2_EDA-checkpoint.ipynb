# %% [markdown]
# # 0. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

from scipy.stats import spearmanr

# %%
corp_time_df = pd.read_csv("data/Corp Ownership and Occupancy Over Time.csv")
zip_neighbor_df = pd.read_csv("data/Boston_Neighborhoods_Zipcodes.csv")
census_corp_time_df = pd.read_csv("data/Census + Corp Ownership and Occupancy Over Time.csv")

# %%
(corp_time_df.equals(census_corp_time_df[['Neighborhood', 'Year', 'own_occ_rate', 'corp_own_rate']]), 
 census_corp_time_df[['Neighborhood', 'Year', 'own_occ_rate', 'corp_own_rate']].equals(corp_time_df))
# Out:
# (True, True)

# %%
census_corp_time_df.head()
# Out:
#   Neighborhood  Year  own_occ_rate  corp_own_rate  college  tot_pop_18plus  \
# 0      Allston  2004          0.29           0.07     3214           26668
# 1      Allston  2005          0.30           0.07     3214           26668
# 2      Allston  2006          0.29           0.08     3214           26668
# 3      Allston  2007          0.31           0.08     3214           26668
# 4      Allston  2008          0.31           0.09     3214           26668
#
#    two_or_more_0_17  aapi_0_17  tot_pop_all  other_18plus  ...  tot_pop_0_17  \
# 0               179        353        28621           273  ...          1953
# 1               179        353        28621           273  ...          1953
# 2               179        353        28621           273  ...          1953
# 3               179        353        28621           273  ...          1953
# 4               179        353        28621           273  ...          1953
#
#    aian_all  tot_gq_pop  occ_unit  aapi_18plus  juvenile  other_all  hisp_all  \
# 0        27        3390     11740         6820         0        330      3657
# 1        27        3390     11740         6820         0        330      3657
# 2        27        3390     11740         6820         0        330      3657
# 3        27        3390     11740         6820         0        330      3657
# 4        27        3390     11740         6820         0        330      3657
#
#    black_18plus  objectid
# 0          1294         1
# 1          1294         1
# 2          1294         1
# 3          1294         1
# 4          1294         1
#
# [5 rows x 40 columns]

# %%
corp_time_df.head()
# Out:
#   Neighborhood  Year  own_occ_rate  corp_own_rate
# 0      Allston  2004          0.29           0.07
# 1      Allston  2005          0.30           0.07
# 2      Allston  2006          0.29           0.08
# 3      Allston  2007          0.31           0.08
# 4      Allston  2008          0.31           0.09

# %%
([hood for hood in census_corp_time_df['Neighborhood'].unique() if hood not in set(zip_neighbor_df['Neighborhood'])],
 [hood for hood in corp_time_df['Neighborhood'].unique() if hood not in set(zip_neighbor_df['Neighborhood'])])
# Out:
# (['Fenway', 'North End', 'West End'], ['Fenway', 'North End', 'West End'])

# %%
# Add missing neighborhoods
add_missing_df = pd.DataFrame([(2215, "Fenway"), (2113, "North End"), (2113, "West End")], 
                              columns=['Zip Code', 'Neighborhood'])
full_zip_neighbor_df = pd.concat([zip_neighbor_df, add_missing_df]).reset_index(drop=True)
full_zip_neighbor_df.to_csv("data/full_zip_map.csv", index=None)

# %%
census_corp_time_df['Neighborhood'].unique()
# Out:
# array(['Allston', 'Beacon Hill', 'Brighton', 'Downtown', 'Charlestown',
#        'Chinatown', 'Dorchester', 'East Boston', 'Fenway', 'Hyde Park',
#        'Jamaica Plain', 'Longwood', 'Mattapan', 'North End', 'Roslindale',
#        'Roxbury', 'South Boston', 'South Boston Waterfront', 'South End',
#        'West End', 'West Roxbury'], dtype=object)

# %%
f, ax = plt.subplots(7, 6, figsize=(15,15))
ax_idx = 0
ax = ax.ravel()
for col in census_corp_time_df.columns:
    if col in ['Neighborhood', 'Year']:
        continue
    census_corp_time_df.drop_duplicates(subset=['Neighborhood'])[col].hist(ax=ax[ax_idx], bins=24)
    ax[ax_idx].grid(visible=False)
    ax[ax_idx].set_title(col, size=14)
    ax_idx += 1
for idx in range(ax_idx, 7*6):
    ax[idx].remove()
f.suptitle("Distribution of every field", size=18, y=0.99)
f.tight_layout()
f.savefig("figures/field_distributions.pdf")
f.savefig("figures/field_distributions.jpeg")

# %%
census_corp_time_df[census_corp_time_df['juvenile']>0]['Neighborhood'].unique()
# Out:
# array(['Brighton', 'Dorchester', 'East Boston', 'Jamaica Plain',
#        'Mattapan', 'Roslindale', 'Roxbury', 'South Boston'], dtype=object)

# %%
census_corp_time_df[census_corp_time_df['black_all']>40000]['Neighborhood'].unique()
# Out:
# array(['Dorchester'], dtype=object)

# %%
census_corp_time_df[census_corp_time_df['college']>10000]
# Out:
#     Neighborhood  Year  own_occ_rate  corp_own_rate  college  tot_pop_18plus  \
# 168       Fenway  2004          0.23           0.09    16197           36715
# 169       Fenway  2005          0.24           0.13    16197           36715
# 170       Fenway  2006          0.23           0.13    16197           36715
# 171       Fenway  2007          0.24           0.13    16197           36715
# 172       Fenway  2008          0.23           0.15    16197           36715
# 173       Fenway  2009          0.23           0.15    16197           36715
# 174       Fenway  2010          0.23           0.16    16197           36715
# 175       Fenway  2011          0.22           0.16    16197           36715
# 176       Fenway  2012          0.21           0.15    16197           36715
# 177       Fenway  2013          0.21           0.16    16197           36715
# 178       Fenway  2014          0.21           0.17    16197           36715
# 179       Fenway  2015          0.19           0.18    16197           36715
# 180       Fenway  2016          0.19           0.21    16197           36715
# 181       Fenway  2017          0.18           0.22    16197           36715
# 182       Fenway  2018          0.17           0.23    16197           36715
# 183       Fenway  2019          0.17           0.24    16197           36715
# 184       Fenway  2020          0.16           0.27    16197           36715
# 185       Fenway  2021          0.16           0.28    16197           36715
# 186       Fenway  2022          0.16           0.29    16197           36715
# 187       Fenway  2023          0.17           0.35    16197           36715
# 188       Fenway  2024          0.16           0.36    16197           36715
#
#      two_or_more_0_17  aapi_0_17  tot_pop_all  other_18plus  ...  \
# 168                99        197        37733           365  ...
# 169                99        197        37733           365  ...
# 170                99        197        37733           365  ...
# 171                99        197        37733           365  ...
# 172                99        197        37733           365  ...
# 173                99        197        37733           365  ...
# 174                99        197        37733           365  ...
# 175                99        197        37733           365  ...
# 176                99        197        37733           365  ...
# 177                99        197        37733           365  ...
# 178                99        197        37733           365  ...
# 179                99        197        37733           365  ...
# 180                99        197        37733           365  ...
# 181                99        197        37733           365  ...
# 182                99        197        37733           365  ...
# 183                99        197        37733           365  ...
# 184                99        197        37733           365  ...
# 185                99        197        37733           365  ...
# 186                99        197        37733           365  ...
# 187                99        197        37733           365  ...
# 188                99        197        37733           365  ...
#
#      tot_pop_0_17  aian_all  tot_gq_pop  occ_unit  aapi_18plus  juvenile  \
# 168          1018        40       16720     12661         9021         0
# 169          1018        40       16720     12661         9021         0
# 170          1018        40       16720     12661         9021         0
# 171          1018        40       16720     12661         9021         0
# 172          1018        40       16720     12661         9021         0
# 173          1018        40       16720     12661         9021         0
# 174          1018        40       16720     12661         9021         0
# 175          1018        40       16720     12661         9021         0
# 176          1018        40       16720     12661         9021         0
# 177          1018        40       16720     12661         9021         0
# 178          1018        40       16720     12661         9021         0
# 179          1018        40       16720     12661         9021         0
# 180          1018        40       16720     12661         9021         0
# 181          1018        40       16720     12661         9021         0
# 182          1018        40       16720     12661         9021         0
# 183          1018        40       16720     12661         9021         0
# 184          1018        40       16720     12661         9021         0
# 185          1018        40       16720     12661         9021         0
# 186          1018        40       16720     12661         9021         0
# 187          1018        40       16720     12661         9021         0
# 188          1018        40       16720     12661         9021         0
#
#      other_all  hisp_all  black_18plus  objectid
# 168        388      3643          2281        10
# 169        388      3643          2281        10
# 170        388      3643          2281        10
# 171        388      3643          2281        10
# 172        388      3643          2281        10
# 173        388      3643          2281        10
# 174        388      3643          2281        10
# 175        388      3643          2281        10
# 176        388      3643          2281        10
# 177        388      3643          2281        10
# 178        388      3643          2281        10
# 179        388      3643          2281        10
# 180        388      3643          2281        10
# 181        388      3643          2281        10
# 182        388      3643          2281        10
# 183        388      3643          2281        10
# 184        388      3643          2281        10
# 185        388      3643          2281        10
# 186        388      3643          2281        10
# 187        388      3643          2281        10
# 188        388      3643          2281        10
#
# [21 rows x 40 columns]

# %%
census_corp_time_df.groupby(['objectid']).apply(lambda x: x['Neighborhood'].unique()).explode().sort_values()
# Out:
# objectid
# 1                     Allston
# 3                 Beacon Hill
# 4                    Brighton
# 5                 Charlestown
# 6                   Chinatown
# 7                  Dorchester
# 8                    Downtown
# 9                 East Boston
# 10                     Fenway
# 12                  Hyde Park
# 13              Jamaica Plain
# 14                   Longwood
# 15                   Mattapan
# 17                  North End
# 18                 Roslindale
# 19                    Roxbury
# 20               South Boston
# 21    South Boston Waterfront
# 22                  South End
# 23                   West End
# 24               West Roxbury
# dtype: object

# %%
f, ax = plt.subplots(1, 1, figsize=(5,5))
ax.scatter(census_corp_time_df[census_corp_time_df['Year']==2024]['corp_own_rate'],
           census_corp_time_df[census_corp_time_df['Year']==2024]['tot_pop_all'])
ax.set_yscale("symlog")

# %%
def get_delta(df, colname):
    df['delta_'+colname] = [np.nan] + list(df[colname].iloc[1:].values - df[colname].iloc[:-1].values)
    return df
census_corp_time_df = census_corp_time_df.groupby('Neighborhood', as_index=False).apply(
    lambda x: get_delta(x.sort_values('Year'), 'own_occ_rate')).reset_index(drop=True)
census_corp_time_df = census_corp_time_df.groupby('Neighborhood', as_index=False).apply(
    lambda x: get_delta(x.sort_values('Year'), 'corp_own_rate')).reset_index(drop=True)

# %%
census_corp_time_df['total_delta_own_occ_rate'] = census_corp_time_df.apply(
    lambda x: np.nan if x['Year']!=2024 else 
    x['own_occ_rate'] - census_corp_time_df[(census_corp_time_df['Neighborhood']==x['Neighborhood']) &
                                            (census_corp_time_df['Year']==2004)].iloc[0]['own_occ_rate'], 1)
census_corp_time_df['total_delta_corp_own_rate'] = census_corp_time_df.apply(
    lambda x: np.nan if x['Year']!=2024 else 
    x['corp_own_rate'] - census_corp_time_df[(census_corp_time_df['Neighborhood']==x['Neighborhood']) &
                                            (census_corp_time_df['Year']==2004)].iloc[0]['corp_own_rate'], 1)
census_corp_time_df.to_csv("data/census_corp_own_occ_time.csv")

# %%
# Compute standard deviation of corporate ownership rates across years
census_corp_time_df.groupby('Year').apply(lambda x: x['corp_own_rate'].std())
# Out:
# Year
# 2004    0.034441
# 2005    0.036279
# 2006    0.035010
# 2007    0.039194
# 2008    0.037632
# 2009    0.036233
# 2010    0.049121
# 2011    0.044374
# 2012    0.036917
# 2013    0.037569
# 2014    0.037499
# 2015    0.041306
# 2016    0.044599
# 2017    0.049140
# 2018    0.050332
# 2019    0.054824
# 2020    0.065152
# 2021    0.072519
# 2022    0.079570
# 2023    0.076020
# 2024    0.079129
# dtype: float64

# %%
# Smallest total change
census_corp_time_df[census_corp_time_df['total_delta_corp_own_rate'].notnull()
                   ].sort_values('total_delta_corp_own_rate')
# Out:
#                 Neighborhood  Year  own_occ_rate  corp_own_rate  college  \
# 209                Hyde Park  2024          0.63           0.12       64
# 440             West Roxbury  2024          0.66           0.13        0
# 314               Roslindale  2024          0.63           0.14        0
# 272                 Mattapan  2024          0.55           0.14        0
# 125               Dorchester  2024          0.48           0.19        0
# 230            Jamaica Plain  2024          0.52           0.17      160
# 104                Chinatown  2024          0.28           0.30      443
# 335                  Roxbury  2024          0.32           0.25     2520
# 356             South Boston  2024          0.38           0.22        0
# 62                  Brighton  2024          0.32           0.23     3493
# 398                South End  2024          0.36           0.25        0
# 293                North End  2024          0.25           0.29        0
# 146                 Downtown  2024          0.30           0.34     3283
# 20                   Allston  2024          0.22           0.30     3214
# 419                 West End  2024          0.27           0.28        0
# 83               Charlestown  2024          0.49           0.28        0
# 251                 Longwood  2024          0.18           0.34     3296
# 41               Beacon Hill  2024          0.29           0.30        0
# 167              East Boston  2024          0.41           0.30        0
# 188                   Fenway  2024          0.16           0.36    16197
# 377  South Boston Waterfront  2024          0.29           0.38        0
#
#      tot_pop_18plus  two_or_more_0_17  aapi_0_17  tot_pop_all  other_18plus  \
# 209           26470               397        115        33009           266
# 440           25457               412        450        31561           157
# 314           23604               461        142        29386           205
# 272           18511               328         96        23834           167
# 125           95365              2456       2485       122191          2736
# 230           34817               708        249        41012           245
# 104            6343                24        560         7143            19
# 335           43502               823        251        54905           837
# 356           33614               272        227        37917           142
# 62            44129               336        579        48330           561
# 398           25922               324        389        29373           169
# 293           10236                40         10        10805            37
# 146           12675               110        158        13451            63
# 20            26668               179        353        28621           273
# 419            7098                76         93         7705            77
# 83            15661               233        246        19120            75
# 251            3977                 7         28         4096            15
# 41             8603                91         15         9336            43
# 167           34826               386        218        43066           491
# 188           36715                99        197        37733           365
# 377            5286                53         24         5579            63
#
#      ...  aapi_18plus  juvenile  other_all  hisp_all  black_18plus  objectid  \
# 209  ...          562         0        347      7901         12229        12
# 440  ...         2001         0        220      3567          2399        24
# 314  ...          876         9        271      7373          4740        18
# 272  ...          394        75        224      4079         12951        15
# 125  ...        10875       286       3541     25285         32678         7
# 230  ...         2736        90        309      8921          3848        13
# 104  ...         3721         0         19       477           254         6
# 335  ...         3026       160       1130     16728         18023        19
# 356  ...         1850        56        191      3887          1084        20
# 62   ...         7222        13        695      4978          1966         4
# 398  ...         4288         0        191      3783          2454        22
# 293  ...          435         0         45       528           132        17
# 146  ...         2128         0         69       961           529         8
# 20   ...         6820         0        330      3657          1294         1
# 419  ...         1347         0         85       613           303        23
# 83   ...         1404         0         98      2075           662         5
# 251  ...          629         0         17       381           304        14
# 41   ...          615         0         46       537           231         3
# 167  ...         1714        12        678     21700          1136         9
# 188  ...         9021         0        388      3643          2281        10
# 377  ...          458         0         67       316           138        21
#
#      delta_own_occ_rate  delta_corp_own_rate  total_delta_own_occ_rate  \
# 209               -0.01                 0.00                     -0.01
# 440                0.00                 0.02                     -0.01
# 314                0.00                 0.02                     -0.05
# 272               -0.01                 0.02                     -0.02
# 125               -0.01                 0.01                     -0.02
# 230               -0.01                 0.01                     -0.04
# 104               -0.01                 0.03                      0.01
# 335                0.00                 0.00                      0.02
# 356               -0.02                 0.01                     -0.12
# 62                 0.00                 0.02                     -0.12
# 398               -0.01                 0.01                     -0.10
# 293               -0.01                 0.01                     -0.11
# 146               -0.01                 0.02                     -0.06
# 20                -0.01                 0.02                     -0.07
# 419               -0.01                 0.01                     -0.16
# 83                -0.02                 0.11                     -0.05
# 251               -0.02                 0.04                     -0.12
# 41                -0.01                 0.02                     -0.05
# 167                0.00                 0.08                     -0.06
# 188               -0.01                 0.01                     -0.07
# 377                0.00                 0.03                      0.05
#
#      total_delta_corp_own_rate
# 209                       0.10
# 440                       0.12
# 314                       0.12
# 272                       0.12
# 125                       0.15
# 230                       0.15
# 104                       0.17
# 335                       0.18
# 356                       0.18
# 62                        0.19
# 398                       0.19
# 293                       0.21
# 146                       0.21
# 20                        0.23
# 419                       0.23
# 83                        0.25
# 251                       0.25
# 41                        0.25
# 167                       0.27
# 188                       0.27
# 377                       0.32
#
# [21 rows x 44 columns]

# %%
spearmanr(census_corp_time_df[census_corp_time_df['Year']==2004]['corp_own_rate'],
              census_corp_time_df[census_corp_time_df['Year']==2024]['corp_own_rate'])
# Out:
# SignificanceResult(statistic=0.8023653123748004, pvalue=1.2101949212217318e-05)

# %%
f, ax = plt.subplots(1, 2, figsize=(14,5))
ax[0].scatter(census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
              census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['corp_own_rate'])
sns.regplot(x=census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
            y=census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['corp_own_rate'],
            ci=95, line_kws={'color':'black', 'linestyle':'dashed'}, ax=ax[0])
ax[1].scatter(census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
              census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['total_delta_corp_own_rate'])
sns.regplot(x=census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
            y=census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['total_delta_corp_own_rate'],
            ci=95, line_kws={'color':'black', 'linestyle':'dashed'}, ax=ax[1])
ax[0].set_ylim((0.05, 0.45))
corp_own_rho, corp_own_pval = spearmanr(census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
                                        census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['corp_own_rate'])
delta_rho, delta_pval = spearmanr(census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
                                  census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['total_delta_corp_own_rate'])
ax[0].text(s=f"ρ: {round(corp_own_rho, 2)}\np-value: {corp_own_pval: .1e}", x=0.0075, y=0.4, size=14)
ax[1].text(s=f"ρ: {round(delta_rho, 2)}\np-value: {delta_pval: .1}", x=0.0075, y=0.32, size=14)
f.text(s="Corporate ownership rate in 2004", size=16, y=-0.05, x=0.375)
ax[0].set_ylabel("Corporate ownership rate in 2024", size=16)
ax[1].set_ylabel("Δcorporate ownership rate\n(2004-2024)", size=16)
ax[0].set_title("Correlation between corporate ownership\nin 2004 and 2024", size=16)
ax[1].set_title("Correlation between corporate ownership in 2004\nand total change in ownership by 2024", size=16)
ax[0].set_xlabel("")
ax[1].set_xlabel("")
f.tight_layout()
f.savefig("images/corp_own_start_end_correlation.jpeg")

# %%
# Same figure as above but converting all axes to ranks
f, ax = plt.subplots(1, 2, figsize=(14,5))
corp_own_rank_2004_s = census_corp_time_df[census_corp_time_df['Year']==2004
                                          ].set_index('Neighborhood')['corp_own_rate'].rank(ascending=False)
corp_own_rank_2024_s = census_corp_time_df[census_corp_time_df['Year']==2024
                                          ].set_index('Neighborhood')['corp_own_rate'].rank(ascending=False)
delta_rank_s = census_corp_time_df[census_corp_time_df['Year']==2024
                                  ].set_index('Neighborhood')['total_delta_corp_own_rate'].rank(ascending=False)


ax[0].scatter(corp_own_rank_2004_s, corp_own_rank_2024_s)
sns.regplot(x=corp_own_rank_2004_s, y=corp_own_rank_2024_s, ci=95, 
            line_kws={'color':'black', 'linestyle':'dashed'}, ax=ax[0])
ax[1].scatter(corp_own_rank_2004_s, delta_rank_s)
sns.regplot(x=corp_own_rank_2004_s, y=delta_rank_s, ci=95,
            line_kws={'color':'black', 'linestyle':'dashed'}, ax=ax[1])
corp_own_rho, corp_own_pval = spearmanr(census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
                                        census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['corp_own_rate'])
delta_rho, delta_pval = spearmanr(census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
                                  census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['total_delta_corp_own_rate'])

ax[0].text(s=f"ρ: {round(corp_own_rho, 2)}\np-value: {corp_own_pval: .1e}", x=1, y=19, size=14)
ax[1].text(s=f"ρ: {round(delta_rho, 2)}\np-value: {delta_pval: .1}", x=1, y=19, size=14)
f.text(s="Rank of corporate ownership rate in 2004", size=16, y=-0.05, x=0.375)
ax[0].set_ylabel("Rank of corporate ownership rate in 2024", size=16)
ax[1].set_ylabel("Rank of Δcorporate ownership rate\n(2004-2024)", size=16)
ax[0].set_title("Correlation between corporate ownership\nin 2004 and 2024", size=16)
ax[1].set_title("Correlation between corporate ownership in 2004\nand total change in ownership by 2024", size=16)
ax[0].set_xlabel("")
ax[1].set_xlabel("")
f.tight_layout()
f.savefig("images/corp_own_start_end_rank_correlation.jpeg")

# %%
f, ax = plt.subplots(1, 2, figsize=(12,5))
corp_own_rank_2004_s = census_corp_time_df[census_corp_time_df['Year']==2004
                                          ].set_index('Neighborhood')['corp_own_rate'].rank(ascending=False)
corp_own_rank_2024_s = census_corp_time_df[census_corp_time_df['Year']==2024
                                          ].set_index('Neighborhood')['corp_own_rate'].rank(ascending=False)
sns.regplot(x=corp_own_rank_2004_s, y=corp_own_rank_2024_s, ci=95, 
            line_kws={'color':'black', 'linestyle':'dashed'}, ax=ax[0])
sns.regplot(x=census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
            y=census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['corp_own_rate'],
            ci=95, line_kws={'color':'black', 'linestyle':'dashed'}, ax=ax[1])
corp_own_rho, corp_own_pval = spearmanr(census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
                                        census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['corp_own_rate'])
ax[0].text(s=f"ρ: {round(corp_own_rho, 2)}\np-value: {corp_own_pval: .1e}", x=1, y=19, size=14)
ax[0].set_ylabel("Rank of corporate ownership rate in 2024", size=14)
ax[0].set_title("Rank correlation between corporate ownership\nin 2004 and 2024", size=16)
ax[0].set_xlabel("Rank of corporate ownership rate in 2004", size=14)
f.tight_layout()
ax[0].set_xticks(range(22)[::5])
ax[0].set_yticks(range(22)[::5])
ax[0].tick_params(axis='both', which='major', labelsize=14)
ax[1].set_ylabel("Corporate ownership rate in 2024", size=14)
ax[1].set_xlabel("Corporate ownership rate in 2004", size=14)
f.savefig("images/corp_own_start_end_rank_correlation.jpeg")

# Delta ownership rate
f, ax = plt.subplots(1, 2, figsize=(12,5))
delta_rank_s = census_corp_time_df[census_corp_time_df['Year']==2024
                                  ].set_index('Neighborhood')['total_delta_corp_own_rate'].rank(ascending=False)
sns.regplot(x=corp_own_rank_2004_s, y=delta_rank_s, ci=95,
            line_kws={'color':'black', 'linestyle':'dashed'}, ax=ax[0])
sns.regplot(x=census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
            y=census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['total_delta_corp_own_rate'],
            ci=95, line_kws={'color':'black', 'linestyle':'dashed'}, ax=ax[1])
delta_rho, delta_pval = spearmanr(census_corp_time_df[census_corp_time_df['Year']==2004].set_index('Neighborhood')['corp_own_rate'],
                                  census_corp_time_df[census_corp_time_df['Year']==2024].set_index('Neighborhood')['total_delta_corp_own_rate'])

ax[0].text(s=f"ρ: {round(delta_rho, 2)}\np-value: {delta_pval: .1}", x=1, y=19, size=14)
ax[0].set_ylabel("Rank of Δcorporate ownership rate\n(2004-2024)", size=16)
ax[0].set_title("Rank correlation between corporate ownership in 2004\nand change in ownership by 2024", size=16)
ax[0].set_xlabel("Rank of corporate ownership rate in 2004", size=16)
ax[0].set_xticks(range(22)[::5])
ax[0].set_yticks(range(22)[::5])
ax[0].tick_params(axis='both', which='major', labelsize=12)
ax[1].set_ylabel("Δcorporate ownership rate\n(2004-2024)", size=14)
ax[1].set_xlabel("Corporate ownership rate in 2004", size=14)
f.tight_layout()
f.savefig("images/delta_corp_own_start_end_rank_correlation.jpeg")

# %%
delta_rank_s.sort_values(), corp_own_rank_2004_s.sort_values()
# Out:
# (Neighborhood
#  South Boston Waterfront     1.0
#  East Boston                 2.5
#  Fenway                      2.5
#  Beacon Hill                 5.0
#  Charlestown                 5.0
#  Longwood                    5.0
#  West End                    7.0
#  Allston                     8.0
#  Downtown                    9.0
#  North End                  10.0
#  Brighton                   11.5
#  South End                  11.5
#  South Boston               13.5
#  Roxbury                    13.5
#  Chinatown                  15.0
#  Jamaica Plain              16.0
#  Dorchester                 17.0
#  Mattapan                   19.0
#  Roslindale                 19.0
#  West Roxbury               19.0
#  Hyde Park                  21.0
#  Name: total_delta_corp_own_rate, dtype: float64,
#  Neighborhood
#  Chinatown                   1.5
#  Downtown                    1.5
#  Fenway                      3.5
#  Longwood                    3.5
#  North End                   5.0
#  Allston                     6.5
#  Roxbury                     6.5
#  South End                   8.5
#  South Boston Waterfront     8.5
#  Beacon Hill                10.5
#  West End                   10.5
#  Brighton                   13.0
#  Dorchester                 13.0
#  South Boston               13.0
#  Charlestown                15.5
#  East Boston                15.5
#  Jamaica Plain              18.5
#  Mattapan                   18.5
#  Hyde Park                  18.5
#  Roslindale                 18.5
#  West Roxbury               21.0
#  Name: corp_own_rate, dtype: float64)
